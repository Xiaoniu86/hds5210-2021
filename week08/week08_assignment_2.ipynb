# %% [markdown]
# # Week 7 Assignment
#
# _MkKinney 6.1_
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  For these exercises, we're going to use two practical examples of fetching data from web pages to show how to use Pandas and BeautifulSoup to extract structured information from the web.
#
# ---
# ---

# %% [markdown]
# ### 33.1 Parsing a list in HTML
#
# Go to the Banner Health Price Transparency Page: https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency
#
# Notice that there is a list of hospitals and the city they are in.  We want to parse the underlying HTML to create a list of all the hospitals along with which city they're in.
#
# ```json
# [
#     ["Banner - University Medical Center Phoenix", "Arizona"],
#     ["Banner - University Medical Center South ", "Arizona"],
#     ...
# ]
# ```
#
# To examine the underlying HTML code, you can use Chrome, right-click, and choose **Inspect**.
#
# For reference, the documentation for BeautifulSoup is here: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup
import requests
headers = { "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36" }

response = requests.get('https://www.bannerhealth.com/patients/billing/pricing-resources/hospital-price-transparency', headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
div = soup.find_all('div', {"class":"col-md-8"})[0]
for hospital_list in div.find_all('ul'):
    state = hospital_list.previous_sibling.previous_sibling.string
    for hospital in hospital_list.find_all('li'):
        print(state, hospital.text)
# Out:
# Arizona Banner - University Medical Center Phoenix
# Arizona Banner - University Medical Center South
# Arizona Banner - University Medical Center Tucson
# Arizona Banner Baywood Medical Center
# Arizona Banner Behavioral Health Hospital
# Arizona Banner Boswell Medical Center
# Arizona Banner Casa Grande Medical Center
# Arizona Banner Del E. Webb Medical Center
# Arizona Banner Desert Medical Center/Cardon Children's Medical Center
# Arizona Banner Estrella Medical Center
# Arizona Banner Gateway Medical Center/Banner MD Anderson Cancer Center
# Arizona Banner Goldfield Medical Center
# Arizona Banner Heart Hospital
# Arizona Banner Ironwood Medical Center
# Arizona Banner Ocotillo Medical Center
# Arizona Banner Payson Medical Center
# Arizona Banner Thunderbird Medical Center
# Arizona Page Hospital
# California Banner Lassen Medical Center
# Colorado Banner Fort Collins Medical Center
# Colorado McKee Medical Center
# Colorado North Colorado Medical Center
# Colorado Sterling Regional Medical Center
# Colorado East Morgan County Hospital
# Nebraska Ogallala Community Hospital
# Nevada Banner Churchill Community Hospital
# Wyoming Banner Wyoming Medical Center
# Wyoming Community Hospital
# Wyoming Washakie Medical Center
# Wyoming Platte County Memorial Hospital
# State-Specific Regulations Arizona
# State-Specific Regulations California
# State-Specific Regulations Colorado
# State-Specific Regulations Nebraska
# State-Specific Regulations Nevada
# State-Specific Regulations Wyoming

# %% [markdown]
# ---
#
# ### 33.2 Using Pandas to Read Tables
#
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/Diagnosis-related_group')
len(tables)
# Out:
# 5

# %%
for index,table in enumerate(tables):
    print("**************TABLE {}".format(index))
    print(table)
# Out:
# **************TABLE 0
#     0                                                  1
# 0 NaN  This article has multiple issues. Please help ...
# 1 NaN  This article needs to be updated. Please updat...
# 2 NaN  This article needs additional citations for ve...
# **************TABLE 1
#     0                                                  1
# 0 NaN  This article needs to be updated. Please updat...
# **************TABLE 2
#     0                                                  1
# 0 NaN  This article needs additional citations for ve...
# **************TABLE 3
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8  \
# 0                                         Description
# 1                              Average length of stay
# 2                      Large urban labor-related rate
# 3                       Large urban non-labor-related
# 4                                          Wage index
# 5   Standard Federal Rate: labor * wage index + no...
# 6                     DRG relative weight (RW) factor
# 7    Weighted payment: Standard Federal Rate * DRG RW
# 8                Disproportionate Share Payment (DSH)
# 9                    Indirect medical education (IME)
# 10                   Total cost outlier reimbursement
# 11  Total operating payment: Weighted payment * (1...
#
#    Hypothetical patient at Generic Hospital in San Francisco, CA, DRG 482, HIP & FEMUR PROCEDURES EXCEPT MAJOR JOINT W/O CC/MCC (2001)[15]:8.1
# 0                                               Value
# 1                                             3.8[16]
# 2                                           $2,809.18
# 3                                           $1,141.85
# 4                                              1.4193
# 5                                           $5,128.92
# 6                                              1.8128
# 7                                           $9,297.71
# 8                                              0.1413
# 9                                              0.0744
# 10                                                 $0
# 11                                         $11,303.23
# **************TABLE 4
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %%
drgs = tables[4]
drgs
# Out:
#      Name  Version       Start date  \
# 0  MS-DRG       25  October 1, 2007
# 1  MS-DRG       26  October 1, 2008
# 2  MS-DRG       27  October 1, 2009
# 3  MS-DRG       31  October 1, 2013
# 4  MS-DRG       32  October 1, 2014
# 5  MS-DRG       33  October 1, 2015
# 6  MS-DRG       34  October 1, 2016
# 7  MS-DRG       35  October 1, 2017
#
#                                                Notes
# 0  Group numbers resequenced, so that for instanc...
# 1  One main change: implementation of Hospital Ac...
# 2  Changes involved are mainly related to Influen...
# 3                                                NaN
# 4                                                NaN
# 5            Convert from ICD-9-CM to ICD-10-CM.[17]
# 6  Address ICD-10 replication issues introduced i...
# 7  MS-DRGs 984 through 986 deleted and reassigned...

# %% [markdown]
# ---
#
# ### 33.3 Find Something of Your Own
#
# Do some web searches and find an HTML page with some data that is interesting to something you're studying.  You can extract and parse that information using either BeautifulSoup or Pandas.  If you're using Pandas, then do something interesting to format and structure your data.  If you're using BeautifulSoup, you'll just need to do the work of parsing the data out of HTML -- that's hard enough!
#
# You don't need to build this as a function.  Just use notebook cells as I've done above.  You will be graded based on _style_.  Use variable names that make sense for your problem / solution. Cleanup anything you don't need before you submit your work.

# %%
# Your Code Here

# %%
import pandas as pd

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/CRISPR_gene_editing')
len(tables)
# Out:
# 4

# %%
for index,table in enumerate(tables):
    print("**************TABLE {}".format(index))
    print(table)
# Out:
# **************TABLE 0
#          Component                                           Function
# 0            crRNA  Contains the guide RNA that locates the correc...
# 1         tracrRNA        Binds to crRNA and forms an active complex.
# 2            sgRNA  Single-guide RNAs are a combined RNA consistin...
# 3             Cas9  An enzyme whose active form is able to modify ...
# 4  Repair template  DNA molecule used as a template in the host ce...
# **************TABLE 1
#                                              Library  \
# 0               Bassik Mouse CRISPR Knockout Library
# 1  Mouse Tumor Suppressor Gene CRISPR Knockout Li...
# 2                     Brie mouse genome-wide library
# 3               Bassik Human CRISPR Knockout Library
# 4                 Brunello human genome-wide library
# 5  Mini-human AsCpf1-based Human Genome-wide Knoc...
#
#                                         ID Species               PI  \
# 0                  1000000121 — 1000000130   Mouse           Bassik
# 1  113584 EFS backbone 113585 TBG backbone   Mouse             Chen
# 2      73632 (1 plasmid) 73633 (2 plasmid)   Mouse  Doench and Root
# 3                          101926 — 101934   Human           Bassik
# 4      73179 (1 plasmid) 73178 (2 plasmid)   Human  Doench and Root
# 5                                   130630   Human          Draetta
#
#               Genes targeted gRNAs per gene    Total gRNAs
# 0  Varies (∼23,000 in total)            ∼10         Varies
# 1                         56             ∼4            286
# 2                      19674              4          78637
# 3  Varies (∼20,500 in total)            ∼10         Varies
# 4                      19114              4          76441
# 5                      16977            3-4  17,032 arrays
# **************TABLE 2
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteScience Breakthroughs of the Year  \
# 0                                     Sciencejournal
#
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}.mw-parser-output .infobox .navbar{font-size:100%}.mw-parser-output .navbox .navbar{display:block;font-size:100%}.mw-parser-output .navbox-title .navbar{float:left;text-align:left;margin-right:0.5em}vteScience Breakthroughs of the Year.1
# 0  1996: HIV understanding 1997: Dolly the sheep ...
# **************TABLE 3
#                    0                                        1
# 0  Authority control  BNF: cb17091624w (data) GND: 1116100770

# %%
df = tables[1]
df
# Out:
#                                              Library  \
# 0               Bassik Mouse CRISPR Knockout Library
# 1  Mouse Tumor Suppressor Gene CRISPR Knockout Li...
# 2                     Brie mouse genome-wide library
# 3               Bassik Human CRISPR Knockout Library
# 4                 Brunello human genome-wide library
# 5  Mini-human AsCpf1-based Human Genome-wide Knoc...
#
#                                         ID Species               PI  \
# 0                  1000000121 — 1000000130   Mouse           Bassik
# 1  113584 EFS backbone 113585 TBG backbone   Mouse             Chen
# 2      73632 (1 plasmid) 73633 (2 plasmid)   Mouse  Doench and Root
# 3                          101926 — 101934   Human           Bassik
# 4      73179 (1 plasmid) 73178 (2 plasmid)   Human  Doench and Root
# 5                                   130630   Human          Draetta
#
#               Genes targeted gRNAs per gene    Total gRNAs
# 0  Varies (∼23,000 in total)            ∼10         Varies
# 1                         56             ∼4            286
# 2                      19674              4          78637
# 3  Varies (∼20,500 in total)            ∼10         Varies
# 4                      19114              4          76441
# 5                      16977            3-4  17,032 arrays

# %%
def color(val):
    color = 'red' if val =='Human' else 'black'
    return 'color: %s' % color

s = df.style.applymap(color)
s
# Out:
# <style  type="text/css" >
#     #T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col0 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col1 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col2 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col3 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col4 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col5 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col6 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col0 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col1 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col2 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col3 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col4 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col5 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col6 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col0 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col1 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col2 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col3 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col4 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col5 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col6 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col0 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col1 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col2 {
#             color:  red;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col3 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col4 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col5 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col6 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row4_col0 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row4_col1 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row4_col2 {
#             color:  red;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row4_col3 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row4_col4 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row4_col5 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row4_col6 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row5_col0 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row5_col1 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row5_col2 {
#             color:  red;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row5_col3 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row5_col4 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row5_col5 {
#             color:  black;
#         }    #T_c27cd21e_9052_11eb_aab7_0ed564d06023row5_col6 {
#             color:  black;
#         }</style><table id="T_c27cd21e_9052_11eb_aab7_0ed564d06023" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Library</th>        <th class="col_heading level0 col1" >ID</th>        <th class="col_heading level0 col2" >Species</th>        <th class="col_heading level0 col3" >PI</th>        <th class="col_heading level0 col4" >Genes targeted</th>        <th class="col_heading level0 col5" >gRNAs per gene</th>        <th class="col_heading level0 col6" >Total gRNAs</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c27cd21e_9052_11eb_aab7_0ed564d06023level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col0" class="data row0 col0" >Bassik Mouse CRISPR Knockout Library</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col1" class="data row0 col1" >1000000121 — 1000000130</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col2" class="data row0 col2" >Mouse</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col3" class="data row0 col3" >Bassik</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col4" class="data row0 col4" >Varies (∼23,000 in total)</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col5" class="data row0 col5" >∼10</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row0_col6" class="data row0 col6" >Varies</td>
#             </tr>
#             <tr>
#                         <th id="T_c27cd21e_9052_11eb_aab7_0ed564d06023level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col0" class="data row1 col0" >Mouse Tumor Suppressor Gene CRISPR Knockout Library</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col1" class="data row1 col1" >113584 EFS backbone 113585 TBG backbone</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col2" class="data row1 col2" >Mouse</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col3" class="data row1 col3" >Chen</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col4" class="data row1 col4" >56</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col5" class="data row1 col5" >∼4</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row1_col6" class="data row1 col6" >286</td>
#             </tr>
#             <tr>
#                         <th id="T_c27cd21e_9052_11eb_aab7_0ed564d06023level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col0" class="data row2 col0" >Brie mouse genome-wide library</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col1" class="data row2 col1" >73632 (1 plasmid) 73633 (2 plasmid)</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col2" class="data row2 col2" >Mouse</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col3" class="data row2 col3" >Doench and Root</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col4" class="data row2 col4" >19674</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col5" class="data row2 col5" >4</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row2_col6" class="data row2 col6" >78637</td>
#             </tr>
#             <tr>
#                         <th id="T_c27cd21e_9052_11eb_aab7_0ed564d06023level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col0" class="data row3 col0" >Bassik Human CRISPR Knockout Library</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col1" class="data row3 col1" >101926 — 101934</td>
#                         <td id="T_c27cd21e_9052_11eb_aab7_0ed564d06023row3_col2" cla

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week08_assignment_2.ipynb
# git commit -a -m "Submitting the week 8 programming assignment"
# git push
# Out:
# Already up to date.
# [main 549fb78] Submitting the week 8 programming assignment
#  2 files changed, 935 insertions(+), 52 deletions(-)
#  create mode 100644 week08/week08_assignment_2.ipynb
# remote: This repository moved. Please use the new location:
# remote:   git@github.com:Xiaoniu86/hds5210-2021.git
# To github.com:xiaoniu86/hds5210-2021.git
#    c8ab4cb..549fb78  main -> main

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 8 programming assignment_ or _Everything is up to date_, then your work was submitted correctly.
